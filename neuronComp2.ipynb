# %%
import tensorflow as tf
from tensorflow.keras import *
from tensorflow.keras.layers import Activation, Dense
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import random
from sklearn.utils import shuffle
import matplotlib
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import time
start=-1
step=(2/9)
num=10

train_x = np.arange(0,num)*step+start
train_y = train_x
test_x = np.arange(0,9)*step+(-1+(1/9))
test_y = test_x
scaler = MinMaxScaler(feature_range=(-1,1))
tmp_data = np.random.rand(1,50)
tmp_x = np.transpose(tmp_data)
scaler.fit(tmp_x)
val_x = np.transpose(scaler.transform(tmp_x))
val_y = val_x
[train_X, train_Y] = np.meshgrid(train_x, train_y)
[test_X, test_Y] = np.meshgrid(test_x, test_y);
[val_X, val_Y] = np.meshgrid(val_x, val_y);
train_Z = np.cos(train_X + 6*0.35*train_Y) + 2.0*0.35*train_X*train_Y
test_Z = np.cos(test_X + 6*0.35*test_Y) + 2.0*0.35*test_X*test_Y
val_Z = np.cos(val_X + 6*0.35*val_Y) + 2.0*0.35*val_X*val_Y
trainx = train_X.flatten()
trainy = train_Y.flatten()
trainData = [trainy, trainx]
trainData = np.array(trainData)
testx = test_X.flatten()
testy = test_Y.flatten()
testData = [testy, testx]
testData = np.array(testData)
trainLabel = np.array(train_Z.flatten())
testLabel = np.array(test_Z.flatten())
valx = val_X.flatten()
valy = val_Y.flatten()
valData = [valy, valx]
valData = np.array(valData)
valLabel = np.array(val_Z.flatten())
trainData = np.transpose(trainData)
trainLabel = np.transpose(trainLabel)
testData = np.transpose(testData)
testLabel = np.transpose(testLabel)
valData = np.transpose(valData)
valLabel = np.transpose(valLabel)
trainLabel = np.reshape(trainLabel, (100, 1))
testLabel = np.reshape(testLabel, (81, 1))
valLabel = np.reshape(valLabel, (2500, 1))
colours = ['r', 'g']
matplotlib.rcParams['contour.negative_linestyle'] = 'solid'
fig, ax = plt.subplots()
testingDim = 9

for iter in range (0, 2):
  if iter == 2:
    model = Sequential()
    model.add(Dense(8, activation='sigmoid'))
    model.add(Dense(2))
    model.compile(optimizer='sgd', loss='mse', metrics=[tf.keras.metrics.MeanSquaredError()])
    monitor = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-3, 
          patience=5, verbose=1, mode='auto',
          restore_best_weights=True)
    model.fit(trainData, trainLabel, validation_data=(valData, valLabel),
          callbacks=[monitor], verbose=2,epochs=100)
    pred = model.predict(testData)
    score = np.sqrt(metrics.mean_squared_error(pred, testLabel)).reshape(testingDim, testingDim)
  else:
    model = Sequential()
    model.add(Dense(8, activation='sigmoid'))
    model.add(Dense(2))
    model.compile(optimizer='sgd', loss='mse', metrics=[tf.keras.metrics.MeanSquaredError()])
    model.fit(trainData, trainLabel, validation_data=(valData, valLabel), verbose=2,epochs=100)
    pred = model.predict(testData)
    score = np.sqrt(metrics.mean_squared_error(pred, testLabel)).reshape(testingDim, testingDim)


  X = []
  Y = []
  for i in range(0, testingDim+2):
    toAddX = []
    toAddY = []
    for j in range(0, testingDim+2):
      if(j > 0 and j < 10 and i > 0 and i < 10):
        toAddY.append((j*(2/10)-1))
        toAddX.append((i*(2/10)-1))
    if(len(toAddX) > 0): X.append(toAddX)
    if(len(toAddY) > 0): Y.append(toAddY)

  X = np.array(X)
  Y = np.array(Y)
  Z = np.array(testLabel).reshape(testingDim, testingDim)

  CS = ax.contour(X, Y, score, 6, colors=colours[iter])
  CS = ax.contour(X, Y, Z, 6, colors='k')


plt.legend()
ax.set_title('Neuron Comparison')
plt.show()
# Out:
# Epoch 1/100
# 4/4 - 1s - loss: 0.4279 - mean_squared_error: 0.4279 - val_loss: 0.3414 - val_mean_squared_error: 0.3414
# Epoch 2/100
# 4/4 - 0s - loss: 0.3898 - mean_squared_error: 0.3898 - val_loss: 0.3127 - val_mean_squared_error: 0.3127
# Epoch 3/100
# 4/4 - 0s - loss: 0.3610 - mean_squared_error: 0.3610 - val_loss: 0.2916 - val_mean_squared_error: 0.2916
# Epoch 4/100
# 4/4 - 0s - loss: 0.3391 - mean_squared_error: 0.3391 - val_loss: 0.2764 - val_mean_squared_error: 0.2764
# Epoch 5/100
# 4/4 - 0s - loss: 0.3233 - mean_squared_error: 0.3233 - val_loss: 0.2652 - val_mean_squared_error: 0.2652
# Epoch 6/100
# 4/4 - 0s - loss: 0.3115 - mean_squared_error: 0.3115 - val_loss: 0.2532 - val_mean_squared_error: 0.2532
# Epoch 7/100
# 4/4 - 0s - loss: 0.2991 - mean_squared_error: 0.2991 - val_loss: 0.2458 - val_mean_squared_error: 0.2458
# Epoch 8/100
# 4/4 - 0s - loss: 0.2913 - mean_squared_error: 0.2913 - val_loss: 0.2400 - val_mean_squared_error: 0.2400
# Epoch 9/100
# 4/4 - 0s - loss: 0.2845 - mean_squared_error: 0.2845 - val_loss: 0.2332 - val_mean_squared_error: 0.2332
# Epoch 10/100
# 4/4 - 0s - loss: 0.2770 - mean_squared_error: 0.2770 - val_loss: 0.2303 - val_mean_squared_error: 0.2303
# Epoch 11/100
# 4/4 - 0s - loss: 0.2738 - mean_squared_error: 0.2738 - val_loss: 0.2255 - val_mean_squared_error: 0.2255
# Epoch 12/100
# 4/4 - 0s - loss: 0.2680 - mean_squared_error: 0.2680 - val_loss: 0.2226 - val_mean_squared_error: 0.2226
# Epoch 13/100
# 4/4 - 0s - loss: 0.2647 - mean_squared_error: 0.2647 - val_loss: 0.2216 - val_mean_squared_error: 0.2216
# Epoch 14/100
# 4/4 - 0s - loss: 0.2635 - mean_squared_error: 0.2635 - val_loss: 0.2198 - val_mean_squared_error: 0.2198
# Epoch 15/100
# 4/4 - 0s - loss: 0.2611 - mean_squared_error: 0.2611 - val_loss: 0.2183 - val_mean_squared_error: 0.2183
# Epoch 16/100
# 4/4 - 0s - loss: 0.2590 - mean_squared_error: 0.2590 - val_loss: 0.2170 - val_mean_squared_error: 0.2170
# Epoch 17/100
# 4/4 - 0s - loss: 0.2570 - mean_squared_error: 0.2570 - val_loss: 0.2169 - val_mean_squared_error: 0.2169
# Epoch 18/100
# 4/4 - 0s - loss: 0.2569 - mean_squared_error: 0.2569 - val_loss: 0.2162 - val_mean_squared_error: 0.2162
# Epoch 19/100
# 4/4 - 0s - loss: 0.2557 - mean_squared_error: 0.2557 - val_loss: 0.2160 - val_mean_squared_error: 0.2160
# Epoch 20/100
# 4/4 - 0s - loss: 0.2555 - mean_squared_error: 0.2555 - val_loss: 0.2155 - val_mean_squared_error: 0.2155
# Epoch 21/100
# 4/4 - 0s - loss: 0.2543 - mean_squared_error: 0.2543 - val_loss: 0.2156 - val_mean_squared_error: 0.2156
# Epoch 22/100
# 4/4 - 0s - loss: 0.2537 - mean_squared_error: 0.2537 - val_loss: 0.2155 - val_mean_squared_error: 0.2155
# Epoch 23/100
# 4/4 - 0s - loss: 0.2532 - mean_squared_error: 0.2532 - val_loss: 0.2161 - val_mean_squared_error: 0.2161
# Epoch 24/100
# 4/4 - 0s - loss: 0.2529 - mean_squared_error: 0.2529 - val_loss: 0.2164 - val_mean_squared_error: 0.2164
# Epoch 25/100
# 4/4 - 0s - loss: 0.2531 - mean_squared_error: 0.2531 - val_loss: 0.2167 - val_mean_squared_error: 0.2167
# Epoch 26/100
# 4/4 - 0s - loss: 0.2534 - mean_squared_error: 0.2534 - val_loss: 0.2163 - val_mean_squared_error: 0.2163
# Epoch 27/100
# 4/4 - 0s - loss: 0.2526 - mean_squared_error: 0.2526 - val_loss: 0.2157 - val_mean_squared_error: 0.2157
# Epoch 28/100
# 4/4 - 0s - loss: 0.2526 - mean_squared_error: 0.2526 - val_loss: 0.2150 - val_mean_squared_error: 0.2150
# Epoch 29/100
# 4/4 - 0s - loss: 0.2525 - mean_squared_error: 0.2525 - val_loss: 0.2151 - val_mean_squared_error: 0.2151
# Epoch 30/100
# 4/4 - 0s - loss: 0.2524 - mean_squared_error: 0.2524 - val_loss: 0.2149 - val_mean_squared_error: 0.2149
# Epoch 31/100
# 4/4 - 0s - loss: 0.2522 - mean_squared_error: 0.2522 - val_loss: 0.2148 - val_mean_squared_error: 0.2148
# Epoch 32/100
# 4/4 - 0s - loss: 0.2521 - mean_squared_error: 0.2521 - val_loss: 0.2152 - val_mean_squared_error: 0.2152
# Epoch 33/100
# 4/4 - 0s - loss: 0.2519 - mean_squared_error: 0.2519 - val_loss: 0.2151 - val_mean_squared_error: 0.2151
# Epoch 34/100
# 4/4 - 0s - loss: 0.2520 - mean_squared_error: 0.2520 - val_loss: 0.2148 - val_mean_squared_error: 0.2148
# Epoch 35/100
# 4/4 - 0s - loss: 0.2517 - mean_squared_error: 0.2517 - val_loss: 0.2148 - val_mean_squared_error: 0.2148
# Epoch 36/100
# 4/4 - 0s - loss: 0.2516 - mean_squared_error: 0.2516 - val_loss: 0.2150 - val_mean_squared_error: 0.2150
# Epoch 37/100
# 4/4 - 0s - loss: 0.2517 - mean_squared_error: 0.2517 - val_loss: 0.2142 - val_mean_squared_error: 0.2142
# Epoch 38/100
# 4/4 - 0s - loss: 0.2514 - mean_squared_error: 0.2514 - val_loss: 0.2146 - val_mean_squared_error: 0.2146
# Epoch 39/100
# 4/4 - 0s - loss: 0.2512 - mean_squared_error: 0.2512 - val_loss: 0.2151 - val_mean_squared_error: 0.2151
# Epoch 40/100
# 4/4 - 0s - loss: 0.2514 - mean_squared_error: 0.2514 - val_loss: 0.2143 - val_mean_squared_error: 0.2143
# Epoch 41/100
# 4/4 - 0s - loss: 0.2510 - mean_squared_error: 0.2510 - val_loss: 0.2143 - val_mean_squared_error: 0.2143
# Epoch 42/100
# 4/4 - 0s - loss: 0.2510 - mean_squared_error: 0.2510 - val_loss: 0.2145 - val_mean_squared_error: 0.2145
# Epoch 43/100
# 4/4 - 0s - loss: 0.2509 - mean_squared_error: 0.2509 - val_loss: 0.2140 - val_mean_squared_error: 0.2140
# Epoch 44/100
# 4/4 - 0s - loss: 0.2508 - mean_squared_error: 0.2508 - val_loss: 0.2143 - val_mean_squared_error: 0.2143
# Epoch 45/100
# 4/4 - 0s - loss: 0.2508 - mean_squared_error: 0.2508 - val_loss: 0.2145 - val_mean_squared_error: 0.2145
# Epoch 46/100
# 4/4 - 0s - loss: 0.2507 - mean_squared_error: 0.2507 - val_loss: 0.2147 - val_mean_squared_error: 0.2147
# Epoch 47/100
# 4/4 - 0s - loss: 0.2507 - mean_squared_error: 0.2507 - val_loss: 0.2144 - val_mean_squared_error: 0.2144
# Epoch 48/100
# 4/4 - 0s - loss: 0.2506 - mean_squared_error: 0.2506 - val_loss: 0.2145 - val_mean_squared_error: 0.2145
# Epoch 49/100
# 4/4 - 0s - loss: 0.2508 - mean_squared_error: 0.2508 - val_loss: 0.2142 - val_mean_squared_error: 0.2142
# Epoch 50/100
# 4/4 - 0s - loss: 0.2506 - mean_squared_error: 0.2506 - val_loss: 0.2134 - val_mean_squared_error: 0.2134
# Epoch 51/100
# 4/4 - 0s - loss: 0.2504 - mean_squared_error: 0.2504 - val_loss: 0.2131 - val_mean_squared_error: 0.2131
# Epoch 52/100
# 4/4 - 0s - loss: 0.2502 - mean_squared_error: 0.2502 - val_loss: 0.2132 - val_mean_squared_error: 0.2132
# Epoch 53/100
# 4/4 - 0s - loss: 0.2502 - mean_squared_error: 0.2502 - val_loss: 0.2134 - val_mean_squared_error: 0.2134
# Epoch 54/100
# 4/4 - 0s - loss: 0.2500 - mean_squared_error: 0.2500 - val_loss: 0.2133 - val_mean_squared_error: 0.2133
# Epoch 55/100
# 4/4 - 0s - loss: 0.2503 - mean_squared_error: 0.2503 - val_loss: 0.2131 - val_mean_squared_error: 0.2131
# Epoch 56/100
# 4/4 - 0s - loss: 0.2498 - mean_squared_error: 0.2498 - val_loss: 0.2124 - val_mean_squared_error: 0.2124
# Epoch 57/100
# 4/4 - 0s - loss: 0.2499 - mean_squared_error: 0.2499 - val_loss: 0.2126 - val_mean_squared_error: 0.2126
# Epoch 58/100
# 4/4 - 0s - loss: 0.2497 - mean_squared_error: 0.2497 - val_loss: 0.2126 - val_mean_squared_error: 0.2126
# Epoch 59/100
# 4/4 - 0s - loss: 0.2497 - mean_squared_error: 0.2497 - val_loss: 0.2131 - val_mean_squared_error: 0.2131
# Epoch 60/100
# 4/4 - 0s - loss: 0.2496 - mean_squared_error: 0.2496 - val_loss: 0.2125 - val_mean_squared_error: 0.2125
# Epoch 61/100
# 4/4 - 0s - loss: 0.2496 - mean_squared_error: 0.2496 - val_loss: 0.2129 - val_mean_squared_error: 0.2129
# Epoch 62/100
# 4/4 - 0s - loss: 0.2493 - mean_squared_error: 0.2493 - val_loss: 0.2123 - val_mean_squared_error: 0.2123
# Epoch 63/100
# 4/4 - 0s - loss: 0.2493 - mean_squared_error: 0.2493 - val_loss: 0.2117 - val_mean_squared_error: 0.2117
# Epoch 64/100
# 4/4 - 0s - loss: 0.2494 - mean_squared_error: 0.2494 - val_loss: 0.2117 - val_mean_squared_error: 0.2117
# Epoch 65/100
# 4/4 - 0s - loss: 0.2492 - mean_squared_error: 0.2492 - val_loss: 0.2119 - val_mean_squared_error: 0.2119
# Epoch 66/100
# 4/4 - 0s - loss: 0.2492 - mean_squared_error: 0.2492 - val_loss: 0.2124 - val_mean_squared_error: 0.2124
# Epoch 67/100
# 4/4 - 0s - loss: 0.2490 - mean_squared_error: 0.2490 - val_loss: 0.2126 - val_mean_squared_error: 0.2126
# Epoch 68/100
# 4/4 - 0s - loss: 0.2489 - mean_squared_error: 0.2489 - val_loss: 0.2127 - val_mean_squared_error: 0.2127
# Epoch 69/100
# 4/4 - 0s - loss: 0.2490 - mean_squared_error: 0.2490 - val_loss: 0.2119 - val_mean_squared_error: 0.2119
# Epoch 70/100
# 4/4 - 0s - loss: 0.2488 - mean_squared_error: 0.2488 - val_loss: 0.2113 - val_mean_squared_error: 0.2113
# Epoch 71/100
# 4/4 - 0s - loss: 0.2488 - mean_squared_error: 0.2488 - val_loss: 0.2113 - val_mean_squared_error: 0.2113
# Epoch 72/100
# 4/4 - 0s - loss: 0.2488 - mean_squared_error: 0.2488 - val_loss: 0.2110 - val_mean_squared_error: 0.2110
# Epoch 73/100
# 4/4 - 0s - loss: 0.2488 - mean_squared_error: 0.2488 - val_loss: 0.2112 - val_mean_squared_error: 0.2112
# Epoch 74/100
# 4/4 - 0s - loss: 0.2485 - mean_squared_error: 0.2485 - val_loss: 0.2112 - val_mean_squared_error: 0.2112
# Epoch 75/100
# 4/4 - 0s - loss: 0.2486 - mean_squared_error: 0.2486 - val_loss: 0.2117 - val_mean_squared_error: 0.2117
# Epoch 76/100
# 4/4 - 0s - loss: 0.2482 - mean_squared_error: 0.2482 - val_loss: 0.2113 - val_mean_squared_error: 0.2113
# Epoch 77/100
# 4/4 - 0s - loss: 0.2483 - mean_squared_error: 0.2483 - val_loss: 0.2118 - val_mean_squared_error: 0.2118
# Epoch 78/100
# 4/4 - 0s - loss: 0.2485 - mean_squared_error: 0.2485 - val_loss: 0.2115 - val_mean_squared_error: 0.2115
# Epoch 79/100
# 4/4 - 0s - loss: 0.2481 - mean_squared_error: 0.2481 - val_loss: 0.2113 - val_mean_squared_error: 0.2113
# Epoch 80/100
# 4/4 - 0s - loss: 0.2480 - mean_squared_error: 0.2480 - val_loss: 0.2117 - val_mean_squared_error: 0.2117
# Epoch 81/100
# 4/4 - 0s - loss: 0.2481 - mean_squared_error: 0.2481 - val_loss: 0.2122 - val_mean_squared_error: 0.2122
# Epoch 82/100
# 4/4 - 0s - loss: 0.2482 - mean_squared_error: 0.2482 - val_loss: 0.2124 - val_mean_squared_error: 0.2124
# Epoch 83/100
# 4/4 - 0s - loss: 0.2482 - mean_squared_error: 0.2482 - val_loss: 0.2135 - val_mean_squared_error: 0.2135
# Epoch 84/100
# 4/4 - 0s - loss: 0.2486 - mean_squared_error: 0.2486 - val_loss: 0.2135 - val_mean_squared_error: 0.2135
# Epoch 85/100
# 4/4 - 0s - loss: 0.2486 - mean_squared_error: 0.2486 - val_loss: 0.2138 - val_mean_squared_error: 0.2138
# Epoch 86/100
# 4/4 - 0s - loss: 0.2486 - mean_squared_error: 0.2486 - val_loss: 0.2126 - val_mean_squared_error: 0.2126
# Epoch 87/100
# 4/4 - 0s - loss: 0.2482 - mean_squared_error: 0.2482 - val_loss: 0.2124 - val_mean_squared_error: 0.2124
# Epoch 88/100
# 4/4 - 0s - loss: 0.2483 - mean_squared_error: 0.2483 - val_loss: 0.2108 - val_mean_squared_error: 0.2108
# Epoch 89/100
# 4/4 - 0s - loss: 0.2474 - mean_squared_error: 0.2474 - val_loss: 0.2107 - val_mean_squared_error: 0.2107
# Epoch 90/100
# 4/4 - 0s - loss: 0.2475 - mean_squared_error: 0.2475 - val_loss: 0.2114 - val_mean_squared_error: 0.2114
# Epoch 91/100
# 4/4 - 0s - loss: 0.2476 - mean_squared_error: 0.2476 - val_loss: 0.2108 - val_mean_squared_error: 0.2108
# Epoch 92/100
# 4/4 - 0s - loss: 0.2473 - mean_squared_error: 0.2473 - val_loss: 0.2111 - val_mean_squared_error: 0.2111
# Epoch 93/100
# 4/4 - 0s - loss: 0.2474 - mean_squared_error: 0.2474 - val_loss: 0.2104 - val_mean_squared_error: 0.2104
# Epoch 94/100
# 4/4 - 0s - loss: 0.2472 - mean_squared_error: 0.2472 - val_loss: 0.2097 - val_mean_squared_error: 0.2097
# Epoch 95/100
# 4/4 - 0s - loss: 0.2472 - mean_squared_error: 0.2472 - val_loss: 0.2098 - val_mean_squared_error: 0.2098
# Epoch 96/100
# 4/4 - 0s - loss: 0.2470 - mean_squared_error: 0.2470 - val_loss: 0.2101 - val_mean_squared_error: 0.2101
# Epoch 97/100
# 4/4 - 0s - loss: 0.2469 - mean_squared_error: 0.2469 - val_loss: 0.2100 - val_mean_squared_error: 0.2100
# Epoch 98/100
# 4/4 - 0s - loss: 0.2469 - mean_squared_error: 0.2469 - val_loss: 0.2103 - val_mean_squared_error: 0.2103
# Epoch 99/100
# 4/4 - 0s - loss: 0.2469 - mean_squared_error: 0.2469 - val_loss: 0.2111 - val_mean_squared_error: 0.2111
# Epoch 100/100
# 4/4 - 0s - loss: 0.2471 - mean_squared_error: 0.2471 - val_loss: 0.2105 - val_mean_squared_error: 0.2105
# Epoch 1/100
# 4/4 - 1s - loss: 0.3297 - mean_squared_error: 0.3297 - val_loss: 0.2687 - val_mean_squared_error: 0.2687
# Epoch 2/100
# 4/4 - 0s - loss: 0.3110 - mean_squared_error: 0.3110 - val_loss: 0.2554 - val_mean_squared_error: 0.2554
# Epoch 3/100
# 4/4 - 0s - loss: 0.2973 - mean_squared_error: 0.2973 - val_loss: 0.2432 - val_mean_squared_error: 0.2432
# Epoch 4/100
# 4/4 - 0s - loss: 0.2847 - mean_squared_error: 0.2847 - val_loss: 0.2357 - val_mean_squared_error: 0.2357
# Epoch 5/100
# 4/4 - 0s - loss: 0.2771 - mean_squared_error: 0.2771 - val_loss: 0.2290 - val_mean_squared_error: 0.2290
# Epoch 6/100
# 4/4 - 0s - loss: 0.2704 - mean_squared_error: 0.2704 - val_loss: 0.2235 - val_mean_squared_error: 0.2235
# Epoch 7/100
# 4/4 - 0s - loss: 0.2644 - mean_squared_error: 0.2644 - val_loss: 0.2191 - val_mean_squared_error: 0.2191
# Epoch 8/100
# 4/4 - 0s - loss: 0.2595 - mean_squared_error: 0.2595 - val_loss: 0.2154 - val_mean_squared_error: 0.2154
# Epoch 9/100
# 4/4 - 0s - loss: 0.2555 - mean_squared_error: 0.2555 - val_loss: 0.2130 - val_mean_squared_error: 0.2130
# Epoch 10/100
# 4/4 - 0s - loss: 0.2524 - mean_squared_error: 0.2524 - val_loss: 0.2113 - val_mean_squared_error: 0.2113
# Epoch 11/100
# 4/4 - 0s - loss: 0.2502 - mean_squared_error: 0.2502 - val_loss: 0.2099 - val_mean_squared_error: 0.2099
# Epoch 12/100
# 4/4 - 0s - loss: 0.2488 - mean_squared_error: 0.2488 - val_loss: 0.2091 - val_mean_squared_error: 0.2091
# Epoch 13/100
# 4/4 - 0s - loss: 0.2480 - mean_squared_error: 0.2480 - val_loss: 0.2083 - val_mean_squared_error: 0.2083
# Epoch 14/100
# 4/4 - 0s - loss: 0.2467 - mean_squared_error: 0.2467 - val_loss: 0.2076 - val_mean_squared_error: 0.2076
# Epoch 15/100
# 4/4 - 0s - loss: 0.2463 - mean_squared_error: 0.2463 - val_loss: 0.2072 - val_mean_squared_error: 0.2072
# Epoch 16/100
# 4/4 - 0s - loss: 0.2459 - mean_squared_error: 0.2459 - val_loss: 0.2067 - val_mean_squared_error: 0.2067
# Epoch 17/100
# 4/4 - 0s - loss: 0.2452 - mean_squared_error: 0.2452 - val_loss: 0.2064 - val_mean_squared_error: 0.2064
# Epoch 18/100
# 4/4 - 0s - loss: 0.2449 - mean_squared_error: 0.2449 - val_loss: 0.2062 - val_mean_squared_error: 0.2062
# Epoch 19/100
# 4/4 - 0s - loss: 0.2448 - mean_squared_error: 0.2448 - val_loss: 0.2060 - val_mean_squared_error: 0.2060
# Epoch 20/100
# 4/4 - 0s - loss: 0.2441 - mean_squared_error: 0.2441 - val_loss: 0.2059 - val_mean_squared_error: 0.2059
# Epoch 21/100
# 4/4 - 0s - loss: 0.2438 - mean_squared_error: 0.2438 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 22/100
# 4/4 - 0s - loss: 0.2443 - mean_squared_error: 0.2443 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 23/100
# 4/4 - 0s - loss: 0.2436 - mean_squared_error: 0.2436 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 24/100
# 4/4 - 0s - loss: 0.2437 - mean_squared_error: 0.2437 - val_loss: 0.2056 - val_mean_squared_error: 0.2056
# Epoch 25/100
# 4/4 - 0s - loss: 0.2440 - mean_squared_error: 0.2440 - val_loss: 0.2056 - val_mean_squared_error: 0.2056
# Epoch 26/100
# 4/4 - 0s - loss: 0.2439 - mean_squared_error: 0.2439 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 27/100
# 4/4 - 0s - loss: 0.2438 - mean_squared_error: 0.2438 - val_loss: 0.2056 - val_mean_squared_error: 0.2056
# Epoch 28/100
# 4/4 - 0s - loss: 0.2431 - mean_squared_error: 0.2431 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 29/100
# 4/4 - 0s - loss: 0.2431 - mean_squared_error: 0.2431 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 30/100
# 4/4 - 0s - loss: 0.2432 - mean_squared_error: 0.2432 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 31/100
# 4/4 - 0s - loss: 0.2431 - mean_squared_error: 0.2431 - val_loss: 0.2059 - val_mean_squared_error: 0.2059
# Epoch 32/100
# 4/4 - 0s - loss: 0.2428 - mean_squared_error: 0.2428 - val_loss: 0.2058 - val_mean_squared_error: 0.2058
# Epoch 33/100
# 4/4 - 0s - loss: 0.2431 - mean_squared_error: 0.2431 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 34/100
# 4/4 - 0s - loss: 0.2435 - mean_squared_error: 0.2435 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 35/100
# 4/4 - 0s - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 36/100
# 4/4 - 0s - loss: 0.2429 - mean_squared_error: 0.2429 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 37/100
# 4/4 - 0s - loss: 0.2428 - mean_squared_error: 0.2428 - val_loss: 0.2062 - val_mean_squared_error: 0.2062
# Epoch 38/100
# 4/4 - 0s - loss: 0.2428 - mean_squared_error: 0.2428 - val_loss: 0.2065 - val_mean_squared_error: 0.2065
# Epoch 39/100
# 4/4 - 0s - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.2066 - val_mean_squared_error: 0.2066
# Epoch 40/100
# 4/4 - 0s - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.2059 - val_mean_squared_error: 0.2059
# Epoch 41/100
# 4/4 - 0s - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.2061 - val_mean_squared_error: 0.2061
# Epoch 42/100
# 4/4 - 0s - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.2061 - val_mean_squared_error: 0.2061
# Epoch 43/100
# 4/4 - 0s - loss: 0.2426 - mean_squared_error: 0.2426 - val_loss: 0.2058 - val_mean_squared_error: 0.2058
# Epoch 44/100
# 4/4 - 0s - loss: 0.2424 - mean_squared_error: 0.2424 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 45/100
# 4/4 - 0s - loss: 0.2424 - mean_squared_error: 0.2424 - val_loss: 0.2063 - val_mean_squared_error: 0.2063
# Epoch 46/100
# 4/4 - 0s - loss: 0.2425 - mean_squared_error: 0.2425 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 47/100
# 4/4 - 0s - loss: 0.2425 - mean_squared_error: 0.2425 - val_loss: 0.2059 - val_mean_squared_error: 0.2059
# Epoch 48/100
# 4/4 - 0s - loss: 0.2423 - mean_squared_error: 0.2423 - val_loss: 0.2060 - val_mean_squared_error: 0.2060
# Epoch 49/100
# 4/4 - 0s - loss: 0.2424 - mean_squared_error: 0.2424 - val_loss: 0.2058 - val_mean_squared_error: 0.2058
# Epoch 50/100
# 4/4 - 0s - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.2061 - val_mean_squared_error: 0.2061
# Epoch 51/100
# 4/4 - 0s - loss: 0.2423 - mean_squared_error: 0.2423 - val_loss: 0.2059 - val_mean_squared_error: 0.2059
# Epoch 52/100
# 4/4 - 0s - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.2056 - val_mean_squared_error: 0.2056
# Epoch 53/100
# 4/4 - 0s - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 54/100
# 4/4 - 0s - loss: 0.2423 - mean_squared_error: 0.2423 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 55/100
# 4/4 - 0s - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 56/100
# 4/4 - 0s - loss: 0.2426 - mean_squared_error: 0.2426 - val_loss: 0.2050 - val_mean_squared_error: 0.2050
# Epoch 57/100
# 4/4 - 0s - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 58/100
# 4/4 - 0s - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.2049 - val_mean_squared_error: 0.2049
# Epoch 59/100
# 4/4 - 0s - loss: 0.2423 - mean_squared_error: 0.2423 - val_loss: 0.2048 - val_mean_squared_error: 0.2048
# Epoch 60/100
# 4/4 - 0s - loss: 0.2428 - mean_squared_error: 0.2428 - val_loss: 0.2049 - val_mean_squared_error: 0.2049
# Epoch 61/100
# 4/4 - 0s - loss: 0.2423 - mean_squared_error: 0.2423 - val_loss: 0.2048 - val_mean_squared_error: 0.2048
# Epoch 62/100
# 4/4 - 0s - loss: 0.2423 - mean_squared_error: 0.2423 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 63/100
# 4/4 - 0s - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 64/100
# 4/4 - 0s - loss: 0.2419 - mean_squared_error: 0.2419 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 65/100
# 4/4 - 0s - loss: 0.2419 - mean_squared_error: 0.2419 - val_loss: 0.2049 - val_mean_squared_error: 0.2049
# Epoch 66/100
# 4/4 - 0s - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.2056 - val_mean_squared_error: 0.2056
# Epoch 67/100
# 4/4 - 0s - loss: 0.2423 - mean_squared_error: 0.2423 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 68/100
# 4/4 - 0s - loss: 0.2423 - mean_squared_error: 0.2423 - val_loss: 0.2067 - val_mean_squared_error: 0.2067
# Epoch 69/100
# 4/4 - 0s - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.2063 - val_mean_squared_error: 0.2063
# Epoch 70/100
# 4/4 - 0s - loss: 0.2424 - mean_squared_error: 0.2424 - val_loss: 0.2058 - val_mean_squared_error: 0.2058
# Epoch 71/100
# 4/4 - 0s - loss: 0.2419 - mean_squared_error: 0.2419 - val_loss: 0.2062 - val_mean_squared_error: 0.2062
# Epoch 72/100
# 4/4 - 0s - loss: 0.2420 - mean_squared_error: 0.2420 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 73/100
# 4/4 - 0s - loss: 0.2419 - mean_squared_error: 0.2419 - val_loss: 0.2050 - val_mean_squared_error: 0.2050
# Epoch 74/100
# 4/4 - 0s - loss: 0.2417 - mean_squared_error: 0.2417 - val_loss: 0.2048 - val_mean_squared_error: 0.2048
# Epoch 75/100
# 4/4 - 0s - loss: 0.2421 - mean_squared_error: 0.2421 - val_loss: 0.2049 - val_mean_squared_error: 0.2049
# Epoch 76/100
# 4/4 - 0s - loss: 0.2417 - mean_squared_error: 0.2417 - val_loss: 0.2049 - val_mean_squared_error: 0.2049
# Epoch 77/100
# 4/4 - 0s - loss: 0.2420 - mean_squared_error: 0.2420 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 78/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2048 - val_mean_squared_error: 0.2048
# Epoch 79/100
# 4/4 - 0s - loss: 0.2417 - mean_squared_error: 0.2417 - val_loss: 0.2046 - val_mean_squared_error: 0.2046
# Epoch 80/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 81/100
# 4/4 - 0s - loss: 0.2419 - mean_squared_error: 0.2419 - val_loss: 0.2050 - val_mean_squared_error: 0.2050
# Epoch 82/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2045 - val_mean_squared_error: 0.2045
# Epoch 83/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2046 - val_mean_squared_error: 0.2046
# Epoch 84/100
# 4/4 - 0s - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.2045 - val_mean_squared_error: 0.2045
# Epoch 85/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2043 - val_mean_squared_error: 0.2043
# Epoch 86/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2042 - val_mean_squared_error: 0.2042
# Epoch 87/100
# 4/4 - 0s - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.2043 - val_mean_squared_error: 0.2043
# Epoch 88/100
# 4/4 - 0s - loss: 0.2417 - mean_squared_error: 0.2417 - val_loss: 0.2044 - val_mean_squared_error: 0.2044
# Epoch 89/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2042 - val_mean_squared_error: 0.2042
# Epoch 90/100
# 4/4 - 0s - loss: 0.2420 - mean_squared_error: 0.2420 - val_loss: 0.2042 - val_mean_squared_error: 0.2042
# Epoch 91/100
# 4/4 - 0s - loss: 0.2417 - mean_squared_error: 0.2417 - val_loss: 0.2042 - val_mean_squared_error: 0.2042
# Epoch 92/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2041 - val_mean_squared_error: 0.2041
# Epoch 93/100
# 4/4 - 0s - loss: 0.2420 - mean_squared_error: 0.2420 - val_loss: 0.2041 - val_mean_squared_error: 0.2041
# Epoch 94/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2041 - val_mean_squared_error: 0.2041
# Epoch 95/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2040 - val_mean_squared_error: 0.2040
# Epoch 96/100
# 4/4 - 0s - loss: 0.2420 - mean_squared_error: 0.2420 - val_loss: 0.2040 - val_mean_squared_error: 0.2040
# Epoch 97/100
# 4/4 - 0s - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.2042 - val_mean_squared_error: 0.2042
# Epoch 98/100
# 4/4 - 0s - loss: 0.2416 - mean_squared_error: 0.2416 - val_loss: 0.2040 - val_mean_squared_error: 0.2040
# Epoch 99/100
# 4/4 - 0s - loss: 0.2417 - mean_squared_error: 0.2417 - val_loss: 0.2040 - val_mean_squared_error: 0.2040
# Epoch 100/100
# 4/4 - 0s - loss: 0.2417 - mean_squared_error: 0.2417 - val_loss: 0.2041 - val_mean_squared_error: 0.2041
# No handles with labels found to put in legend.
